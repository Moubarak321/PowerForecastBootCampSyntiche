# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
current_dir = os.getcwd()

if "notebook" in current_dir:
    current_dir = current_dir.split("notebook")[0]
    os.chdir(current_dir)

# Change the current working directory
print(current_dir)

from src import data_gathering, data_analysis, training, data_featuring
# Out:
# P:\Projets\Forecasting\

# %% [markdown]
# ## Chargement les données

# %%
# Charger les données à partir du fichier csv
data_filename = "data/PowerConsumptionTetouan/Tetuan_City_power_consumption.csv"
df_dataset = data_gathering.load_dataset(data_filename, col_sep=",", b_rename_cols=True)

# %% [markdown]
# ## Définition des paramètres

# %%
# Paramètres des entrées et sortie
target_cols = ["Consumption_Z3"]
inputs_cols = ['Temperature', 'Humidity', 'WindSpeed', target_cols[0]]

# Paramètres pour la création des bases de test et d'apprentissage
train_ratio = 0.8
win_size_hours = 1
time_sampling_mins = 10
b_scaler = True
scaler_str = "std"

# %% [markdown]
# ## Création des bases d'apprentissage et de test

# %% [markdown]
# #### Séparation temporelles des bases d'apprentissage et de test

# %%
d_train_test, scaler = training.build_train_test_datasets(df_data=df_dataset,
                                                          input_cols=inputs_cols, 
                                                          target_cols=target_cols,
                                                          train_ratio=train_ratio, 
                                                          scaler_str=scaler_str)

df_train_inputs = d_train_test["Scaled"]["train"]["Inputs"]
df_train_targets = d_train_test["Scaled"]["train"]["Target"]
df_test_inputs = d_train_test["Scaled"]["test"]["Inputs"]
df_test_targets = d_train_test["Scaled"]["test"]["Target"]

# %% [markdown]
# #### Création des séquences temporelles
# Il faudra structurer les données en séquences temporelles afin de prendre en compte un historique

# %%
X_train, y_train, idx_train = training.build_sequences(df_data=df_train_inputs,
                                                       df_targets=df_train_targets,
                                                       win_size_hours=win_size_hours,
                                                       time_sampling_mins=time_sampling_mins)

X_test, y_test, idx_test = training.build_sequences(df_data=df_test_inputs,
                                                    df_targets=df_test_targets,
                                                    win_size_hours=win_size_hours,
                                                    time_sampling_mins=time_sampling_mins)

# %% [markdown]
# ## Prédiction de la consommation

# %% [markdown]
# ### Entrainement du modèle

# %%
import os
from datetime import datetime
import pickle

# Paramètres d'apprentissage
d_learning_params = dict()
d_learning_params['batch_size'] = 512
d_learning_params['epochs'] = 500
d_learning_params['activation_fn'] = "relu"
d_learning_params['loss_fn'] = "mse"
d_learning_params['optimizer'] = "adam"
d_learning_params['val_ratio'] = 0.2
d_learning_params['win_size_hours'] = win_size_hours
d_learning_params['time_sampling_mins'] = time_sampling_mins
d_learning_params['scaler'] = scaler
d_learning_params['feat_names'] = inputs_cols
d_learning_params['target_names'] = target_cols
d_learning_params['metrics'] = ['mae']
d_learning_params['d_train_test'] = d_train_test
d_learning_params['seq_train_test'] = {"train":{"features":X_train, "targets":y_train, "targets_idx": idx_train},
                                       "test":{"features":X_test, "targets":y_test, "targets_idx": idx_test}}
d_learning_params['layers'] = [150, 80, 30, 10]

# Récupérer la date et l'heure pour la création du fichier du modèle
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
results_dir = os.path.join("models", "LSTM_{}h".format(win_size_hours), target_cols[0], current_datetime)
params_file = os.path.join(results_dir, "lstm_params_{}.pkl".format(str(current_datetime)))

# Création du répertoire de sauvegarde des résultats s'il n'existe pas déjà
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

# Sauvergarde des paramètres d'appentissag
with open(params_file, 'wb') as fp:
    pickle.dump(d_learning_params, fp)

model_lstm, scores = training.train_lstm(X_train, y_train,
                                         X_test, y_test, 
                                         d_learning_params,
                                         results_dir)

# Sauvegarder les scores de ce modèle
d_scores = d_learning_params.copy()
d_scores["scores"] = scores
scores_file = os.path.join(results_dir, "lstm_scores_{}.pkl".format(str(current_datetime)))

print("Performance du modèle")
print("\t --> Score R2 (Le modèle parfait a un score de 1)")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['R2']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['R2']['test']))
print("\n")
print("\t --> MAE (Erreur moyenne absolue) en KW")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['MAE']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['MAE']['test']))

# Sauvergarde des paramètres d'appentissag
with open(scores_file, 'wb') as fp:
    pickle.dump(d_scores, fp)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 150)            93000
#
#  lstm_1 (LSTM)               (None, 6, 80)             73920
#
#  lstm_2 (LSTM)               (None, 6, 30)             13320
#
#  lstm_3 (LSTM)               (None, 10)                1640
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 181,891
# Trainable params: 181,891
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 33/33 [==============================] - 9s 168ms/step - loss: 450360832.0000 - mae: 20189.7773 - val_loss: 259513888.0000 - val_mae: 15475.1543
# Epoch 2/500
# 33/33 [==============================] - 5s 163ms/step - loss: 227676288.0000 - mae: 13131.3760 - val_loss: 79883560.0000 - val_mae: 8240.9385
# Epoch 3/500
# 33/33 [==============================] - 5s 166ms/step - loss: 40627980.0000 - mae: 5002.5864 - val_loss: 12475624.0000 - val_mae: 2678.2866
# Epoch 4/500
# 33/33 [==============================] - 6s 168ms/step - loss: 11652636.0000 - mae: 2561.2742 - val_loss: 11040207.0000 - val_mae: 2502.6260
# Epoch 5/500
# 33/33 [==============================] - 5s 167ms/step - loss: 7441485.5000 - mae: 1975.3008 - val_loss: 9579248.0000 - val_mae: 2360.3440
# Epoch 6/500
# 33/33 [==============================] - 5s 158ms/step - loss: 6050839.5000 - mae: 1743.4814 - val_loss: 7701356.5000 - val_mae: 2127.3660
# Epoch 7/500
# 33/33 [==============================] - 5s 162ms/step - loss: 5378505.5000 - mae: 1617.5073 - val_loss: 7085750.5000 - val_mae: 2095.3618
# Epoch 8/500
# 33/33 [==============================] - 5s 161ms/step - loss: 4987941.5000 - mae: 1543.5559 - val_loss: 6418134.0000 - val_mae: 2011.1523
# Epoch 9/500
# 33/33 [==============================] - 5s 162ms/step - loss: 4741687.5000 - mae: 1495.8889 - val_loss: 5245415.0000 - val_mae: 1804.3727
# Epoch 10/500
# 33/33 [==============================] - 5s 157ms/step - loss: 4598635.0000 - mae: 1464.7561 - val_loss: 5412789.5000 - val_mae: 1874.3917
# Epoch 11/500
# 33/33 [==============================] - 5s 164ms/step - loss: 4458576.5000 - mae: 1436.9916 - val_loss: 5116164.0000 - val_mae: 1824.7323
# Epoch 12/500
# 33/33 [==============================] - 5s 159ms/step - loss: 4374401.5000 - mae: 1419.6190 - val_loss: 4812445.5000 - val_mae: 1776.8064
# Epoch 13/500
# 33/33 [==============================] - 5s 159ms/step - loss: 4307161.0000 - mae: 1406.4717 - val_loss: 4597332.5000 - val_mae: 1732.0660
# Epoch 14/500
# 33/33 [==============================] - 5s 160ms/step - loss: 4247023.5000 - mae: 1392.8091 - val_loss: 4206916.5000 - val_mae: 1642.0471
# Epoch 15/500
# 33/33 [==============================] - 5s 159ms/step - loss: 4197499.5000 - mae: 1383.2074 - val_loss: 4134867.0000 - val_mae: 1643.4464
# Epoch 16/500
# 33/33 [==============================] - 5s 160ms/step - loss: 4150946.7500 - mae: 1373.9200 - val_loss: 3772581.7500 - val_mae: 1535.7681
# Epoch 17/500
# 33/33 [==============================] - 5s 158ms/step - loss: 4122424.2500 - mae: 1366.0222 - val_loss: 3546712.5000 - val_mae: 1491.5405
# Epoch 18/500
# 33/33 [==============================] - 5s 159ms/step - loss: 4079226.2500 - mae: 1359.6125 - val_loss: 3890991.2500 - val_mae: 1596.6057
# Epoch 19/500
# 33/33 [==============================] - 5s 160ms/step - loss: 4050036.5000 - mae: 1355.2384 - val_loss: 3468988.5000 - val_mae: 1471.2944
# Epoch 20/500
# 33/33 [==============================] - 5s 155ms/step - loss: 4019436.2500 - mae: 1346.5624 - val_loss: 3612831.2500 - val_mae: 1521.5131
# Epoch 21/500
# 33/33 [==============================] - 5s 157ms/step - loss: 3984596.5000 - mae: 1340.1755 - val_loss: 3722287.7500 - val_mae: 1566.9893
# Epoch 22/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3986858.7500 - mae: 1343.9897 - val_loss: 3192608.2500 - val_mae: 1403.1897
# Epoch 23/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3933946.7500 - mae: 1331.9120 - val_loss: 3465400.7500 - val_mae: 1492.7128
# Epoch 24/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3906000.7500 - mae: 1325.5048 - val_loss: 3250369.5000 - val_mae: 1427.6460
# Epoch 25/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3883009.7500 - mae: 1323.0359 - val_loss: 3278609.0000 - val_mae: 1440.8937
# Epoch 26/500
# 33/33 [==============================] - 5s 165ms/step - loss: 3874043.0000 - mae: 1321.6466 - val_loss: 2988233.0000 - val_mae: 1343.4175
# Epoch 27/500
# 33/33 [==============================] - 5s 159ms/step - loss: 3856878.2500 - mae: 1319.9197 - val_loss: 3247698.5000 - val_mae: 1440.3805
# Epoch 28/500
# 33/33 [==============================] - 5s 160ms/step - loss: 3827369.0000 - mae: 1315.2854 - val_loss: 3059857.2500 - val_mae: 1375.9379
# Epoch 29/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3816690.2500 - mae: 1311.6401 - val_loss: 3384665.7500 - val_mae: 1496.7377
# Epoch 30/500
# 33/33 [==============================] - 5s 160ms/step - loss: 3812098.7500 - mae: 1316.7079 - val_loss: 3120521.7500 - val_mae: 1410.8662
# Epoch 31/500
# 33/33 [==============================] - 5s 160ms/step - loss: 3760926.0000 - mae: 1306.2518 - val_loss: 2941204.2500 - val_mae: 1348.3595
# Epoch 32/500
# 33/33 [==============================] - 5s 158ms/step - loss: 3837456.5000 - mae: 1330.9072 - val_loss: 3281746.0000 - val_mae: 1468.9546
# Epoch 33/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3687244.7500 - mae: 1289.4606 - val_loss: 2801645.2500 - val_mae: 1298.5194
# Epoch 34/500
# 33/33 [==============================] - 5s 158ms/step - loss: 3642378.7500 - mae: 1279.6215 - val_loss: 2917558.7500 - val_mae: 1352.2139
# Epoch 35/500
# 33/33 [==============================] - 5s 161ms/step - loss: 3619136.7500 - mae: 1280.4321 - val_loss: 2677755.5000 - val_mae: 1267.9304
# Epoch 36/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3576439.0000 - mae: 1273.8578 - val_loss: 2467486.5000 - val_mae: 1165.5114
# Epoch 37/500
# 33/33 [==============================] - 5s 158ms/step - loss: 3475202.2500 - mae: 1256.9994 - val_loss: 2718180.5000 - val_mae: 1281.1427
# Epoch 38/500
# 33/33 [==============================] - 5s 158ms/step - loss: 3398961.5000 - mae: 1240.2313 - val_loss: 2672215.7500 - val_mae: 1269.2108
# Epoch 39/500
# 33/33 [==============================] - 5s 160ms/step - loss: 3261417.0000 - mae: 1214.4315 - val_loss: 2743650.0000 - val_mae: 1308.2936
# Epoch 40/500
# 33/33 [==============================] - 5s 162ms/step - loss: 3147758.2500 - mae: 1199.0339 - val_loss: 2706999.5000 - val_mae: 1298.6598
# Epoch 41/500
# 33/33 [==============================] - 5s 163ms/step - loss: 2946512.0000 - mae: 1162.6226 - val_loss: 2323660.7500 - val_mae: 1145.3075
# Epoch 42/500
# 33/33 [==============================] - 5s 161ms/step - loss: 2938940.0000 - mae: 1182.5321 - val_loss: 3081019.7500 - val_mae: 1433.8644
# Epoch 43/500
# 33/33 [==============================] - 5s 156ms/step - loss: 2858941.0000 - mae: 1175.7638 - val_loss: 1791349.3750 - val_mae: 953.6183
# Epoch 44/500
# 33/33 [==============================] - 5s 158ms/step - loss: 2535189.2500 - mae: 1084.5491 - val_loss: 2603577.5000 - val_mae: 1256.5848
# Epoch 45/500
# 33/33 [==============================] - 5s 156ms/step - loss: 2245044.2500 - mae: 1023.7737 - val_loss: 2578208.7500 - val_mae: 1255.2861
# Epoch 46/500
# 33/33 [==============================] - 5s 157ms/step - loss: 2097002.7500 - mae: 1001.0932 - val_loss: 2720897.0000 - val_mae: 1291.0406
# Epoch 47/500
# 33/33 [==============================] - 5s 159ms/step - loss: 2137495.5000 - mae: 1014.7628 - val_loss: 2619069.0000 - val_mae: 1323.1909
# Epoch 48/500
# 33/33 [==============================] - 5s 158ms/step - loss: 1808163.3750 - mae: 931.3234 - val_loss: 2409380.7500 - val_mae: 1209.8845
# Epoch 49/500
# 33/33 [==============================] - 5s 160ms/step - loss: 2224524.5000 - mae: 1065.3533 - val_loss: 2640568.0000 - val_mae: 1369.1246
# Epoch 50/500
# 33/33 [==============================] - 5s 162ms/step - loss: 1833560.1250 - mae: 942.4779 - val_loss: 2461141.0000 - val_mae: 1263.6238
# Epoch 51/500
# 33/33 [==============================] - 5s 162ms/step - loss: 1571801.3750 - mae: 864.4970 - val_loss: 2280526.7500 - val_mae: 1192.5089
# Epoch 52/500
# 33/33 [==============================] - 5s 158ms/step - loss: 1860885.7500 - mae: 981.6781 - val_loss: 2246843.7500 - val_mae: 1179.7947
# Epoch 53/500
# 33/33 [==============================] - 5s 155ms/step - loss: 1581617.3750 - mae: 873.1129 - val_loss: 1966383.0000 - val_mae: 1077.4540
# Epoch 54/500
# 33/33 [==============================] - 5s 160ms/step - loss: 1282383.0000 - mae: 773.2366 - val_loss: 1707165.2500 - val_mae: 996.5272
# Epoch 55/500
# 33/33 [==============================] - 5s 159ms/step - loss: 1837916.6250 - mae: 976.6118 - val_loss: 1683642.5000 - val_mae: 1013.0284
# Epoch 56/500
# 33/33 [==============================] - 5s 158ms/step - loss: 1404122.3750 - mae: 812.2870 - val_loss: 1832027.1250 - val_mae: 1050.3947
# Epoch 57/500
# 33/33 [==============================] - 5s 160ms/step - loss: 1157490.1250 - mae: 742.1125 - val_loss: 1458581.6250 - val_mae: 898.3699
# Epoch 58/500
# 33/33 [==============================] - 5s 159ms/step - loss: 1304224.1250 - mae: 805.1598 - val_loss: 1521107.1250 - val_mae: 998.2777
# Epoch 59/500
# 33/33 [==============================] - 5s 159ms/step - loss: 1318901.7500 - mae: 817.1246 - val_loss: 1990810.1250 - val_mae: 1186.3298
# Epoch 60/500
# 33/33 [==============================] - 5s 159ms/step - loss: 1293657.6250 - mae: 800.4157 - val_loss: 1388944.3750 - val_mae: 938.3389
# Epoch 61/500
# 33/33 [==============================] - 5s 163ms/step - loss: 1130180.3750 - mae: 740.1916 - val_loss: 1096825.6250 - val_mae: 776.8740
# Epoch 62/500
# 33/33 [==============================] - 5s 160ms/step - loss: 1009848.6250 - mae: 686.9479 - val_loss: 1064067.7500 - val_mae: 769.3078
# Epoch 63/500
# 33/33 [==============================] - 5s 161ms/step - loss: 906576.6875 - mae: 646.2986 - val_loss: 1277890.1250 - val_mae: 882.1548
# Epoch 64/500
# 33/33 [==============================] - 5s 161ms/step - loss: 846841.4375 - mae: 622.1913 - val_loss: 993615.4375 - val_mae: 721.4672
# Epoch 65/500
# 33/33 [==============================] - 5s 162ms/step - loss: 1065731.3750 - mae: 726.5424 - val_loss: 945194.3750 - val_mae: 703.2180
# Epoch 66/500
# 33/33 [==============================] - 5s 160ms/step - loss: 874360.8125 - mae: 631.6054 - val_loss: 1129443.5000 - val_mae: 817.5175
# Epoch 67/500
# 33/33 [==============================] - 5s 158ms/step - loss: 912972.5625 - mae: 641.6962 - val_loss: 1202298.8750 - val_mae: 832.2268
# Epoch 68/500
# 33/33 [==============================] - 5s 158ms/step - loss: 1001514.4375 - mae: 704.1149 - val_loss: 1213631.7500 - val_mae: 863.7573
# Epoch 69/500
# 33/33 [==============================] - 5s 159ms/step - loss: 970113.1250 - mae: 682.4021 - val_loss: 1099684.0000 - val_mae: 798.0352
# Epoch 70/500
# 33/33 [==============================] - 5s 162ms/step - loss: 757974.1875 - mae: 575.0658 - val_loss: 969326.1250 - val_mae: 708.4275
# Epoch 71/500
# 33/33 [==============================] - 5s 164ms/step - loss: 774746.9375 - mae: 586.4053 - val_loss: 888165.1250 - val_mae: 680.4587
# Epoch 72/500
# 33/33 [==============================] - 5s 161ms/step - loss: 814499.4375 - mae: 614.3613 - val_loss: 988597.0000 - val_mae: 740.1386
# Epoch 73/500
# 33/33 [==============================] - 5s 161ms/step - loss: 738772.8750 - mae: 569.8715 - val_loss: 899673.0625 - val_mae: 668.1926
# Epoch 74/500
# 33/33 [==============================] - 5s 161ms/step - loss: 780418.0000 - mae: 597.7203 - val_loss: 1022973.5000 - val_mae: 749.2191
# Epoch 75/500
# 33/33 [==============================] - 5s 163ms/step - loss: 765829.0625 - mae: 590.3100 - val_loss: 765376.1250 - val_mae: 594.7221
# Epoch 76/500
# 33/33 [==============================] - 5s 163ms/step - loss: 751783.3125 - mae: 578.8352 - val_loss: 873097.8750 - val_mae: 659.6318
# Epoch 77/500
# 33/33 [==============================] - 5s 159ms/step - loss: 903429.3750 - mae: 665.6074 - val_loss: 1029031.3750 - val_mae: 767.0015
# Epoch 78/500
# 33/33 [==============================] - 5s 163ms/step - loss: 688563.7500 - mae: 544.2301 - val_loss: 851738.3125 - val_mae: 647.8889
# Epoch 79/500
# 33/33 [==============================] - 5s 166ms/step - loss: 863921.2500 - mae: 646.0342 - val_loss: 908485.2500 - val_mae: 708.1428
# Epoch 80/500
# 33/33 [==============================] - 5s 161ms/step - loss: 756038.7500 - mae: 581.8502 - val_loss: 932503.3125 - val_mae: 710.2883
# Epoch 81/500
# 33/33 [==============================] - 5s 159ms/step - loss: 679054.1875 - mae: 541.6281 - val_loss: 882599.0625 - val_mae: 671.8450
# Epoch 82/500
# 33/33 [==============================] - 5s 159ms/step - loss: 665285.8750 - mae: 536.0161 - val_loss: 792118.5000 - val_mae: 620.8589
# Epoch 83/500
# 33/33 [==============================] - 5s 159ms/step - loss: 656668.0625 - mae: 532.3348 - val_loss: 800717.5625 - val_mae: 623.0432
# Epoch 84/500
# 33/33 [==============================] - 5s 159ms/step - loss: 647976.5625 - mae: 526.8827 - val_loss: 802808.9375 - val_mae: 621.4368
# Epoch 85/500
# 33/33 [==============================] - 5s 161ms/step - loss: 661453.5000 - mae: 540.3664 - val_loss: 929411.0625 - val_mae: 704.0435
# Epoch 86/500
# 33/33 [==============================] - 5s 163ms/step - loss: 677519.6875 - mae: 548.2454 - val_loss: 784732.3750 - val_mae: 611.5650
# Epoch 87/500
# 33/33 [==============================] - 5s 160ms/step - loss: 702277.3750 - mae: 568.8038 - val_loss: 785849.6875 - val_mae: 619.8969
# Epoch 88/500
# 33/33 [==============================] - 5s 164ms/step - loss: 697053.7500 - mae: 563.2097 - val_loss: 977375.0625 - val_mae: 729.6133
# Epoch 89/500
# 33/33 [==============================] - 5s 157ms/step - loss: 691463.4375 - mae: 562.0156 - val_loss: 1089121.2500 - val_mae: 799.8563
# Epoch 90/500
# 33/33 [==============================] - 5s 159ms/step - loss: 814081.1875 - mae: 634.8522 - val_loss: 793875.3125 - val_mae: 611.3710
# 328/328 [==============================] - 1s 2ms/step
# 1311/1311 [==============================] - 3s 2ms/step
# Performance du modèle
# 	 --> Score R2 (Le modèle parfait a un score de 1)
# 	 	 --> Ensemble d'apprentissage : 0.981
# 	 	 --> Ensemble de test : 0.897
#
#
# 	 --> MAE (Erreur moyenne absolue) en KW
# 	 	 --> Ensemble d'apprentissage : 618.267
# 	 	 --> Ensemble de test : 814.352

# %% [markdown]
# ### Affichage des prédictions

# %%
from src.prediction import display_prediction
pred_col_name = ["prediction"]

# Calculer les prédictions
df_test = pd.DataFrame(data=y_test, columns=target_cols,index=idx_test)
df_test[pred_col_name[0]] = model_lstm.predict(X_test)

# Sauvegarde des résultats
df_test.to_pickle(os.path.join(results_dir, "lstm_predictions_{}_{}.pkl".format(target_cols[0], str(current_datetime))))

# Afficher les résultats
display_prediction(df_test, target_col_name=target_cols[0],
                   pred_col_name=pred_col_name, figsize=(14, 8))
# Out:
# 328/328 [==============================] - 1s 3ms/step

# %%
df_test["2017-10-20":"2017-10-30"].plot()
# Out:
# <Axes: >
