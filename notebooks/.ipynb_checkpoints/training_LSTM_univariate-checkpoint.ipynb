# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
current_dir = os.getcwd()

if "notebook" in current_dir:
    current_dir = current_dir.split("notebook")[0]
    os.chdir(current_dir)

# Change the current working directory
print(current_dir)

from src import data_gathering, data_analysis, training, data_featuring
# Out:
# P:\Projets\Forecasting\

# %% [markdown]
# ## Chargement les données

# %%
# Charger les données à partir du fichier csv
data_filename = "data/PowerConsumptionTetouan/Tetuan_City_power_consumption.csv"
df_dataset = data_gathering.load_dataset(data_filename, col_sep=",", b_rename_cols=True)

# %% [markdown]
# ## Définition des paramètres

# %%
# Paramètres des entrées et sortie
feat_name = "Consumption_Z1"

# Paramètres pour la création des bases de test et d'apprentissage
train_ratio = 0.8
win_size_hours = 1
time_sampling_mins = 10
b_scaler = True
scaler_str = "std"

# %% [markdown]
# ## Création des bases d'apprentissage et de test

# %% [markdown]
# #### Séparation temporelles des bases d'apprentissage et de test

# %% [markdown]
# #### Création des séquences temporelles
# Il faudra structurer les données en séquences temporelles afin de prendre en compte un historique

# %%
X_train, y_train, idx_train, X_test, y_test, idx_test, scaler = \
training.build_train_test_univariate_sequences(df_data=df_dataset,
                                               feat_name=feat_name,
                                               win_size_hours=win_size_hours,
                                               time_sampling_mins=time_sampling_mins,
                                               train_ratio=train_ratio,
                                               scaler_str=scaler_str)

# %% [markdown]
# ## Prédiction de la consommation

# %% [markdown]
# ### Entrainement du modèle

# %%
import os
from datetime import datetime
import pickle

# Paramètres d'apprentissage
d_learning_params = dict()
d_learning_params['batch_size'] = 512
d_learning_params['epochs'] = 500
d_learning_params['activation_fn'] = "relu"
d_learning_params['loss_fn'] = "mse"
d_learning_params['optimizer'] = "adam"
d_learning_params['val_ratio'] = 0.2
d_learning_params['win_size_hours'] = win_size_hours
d_learning_params['time_sampling_mins'] = time_sampling_mins
d_learning_params['scaler'] = scaler
d_learning_params['feat_names'] = feat_name
d_learning_params['target_names'] = feat_name
d_learning_params['metrics'] = ['mae']
d_learning_params['d_train_test'] = {}
d_learning_params['seq_train_test'] = {"train":{"features":X_train, "targets":y_train, "targets_idx": idx_train},
                                       "test":{"features":X_test, "targets":y_test, "targets_idx": idx_test}}
d_learning_params['layers'] = [100, 50, 10]

# Récupérer la date et l'heure pour la création du fichier du modèle
current_datetime = datetime.now().strftime("%Y%m%d_%H%M%S")
results_dir = os.path.join("models", "Univariate_LSTM_{}h".format(win_size_hours), feat_name, current_datetime)
params_file = os.path.join(results_dir, "lstm_params_{}.pkl".format(str(current_datetime)))

# Création du répertoire de sauvegarde des résultats s'il n'existe pas déjà
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

# Sauvergarde des paramètres d'appentissag
with open(params_file, 'wb') as fp:
    pickle.dump(d_learning_params, fp)

model_lstm, scores = training.train_lstm_univariate(X_train, y_train,
                                         X_test, y_test, 
                                         d_learning_params,
                                         results_dir)

# Sauvegarder les scores de ce modèle
d_scores = d_learning_params.copy()
d_scores["scores"] = scores
scores_file = os.path.join(results_dir, "lstm_scores_{}.pkl".format(str(current_datetime)))

print("Performance du modèle")
print("\t --> Score R2 (Le modèle parfait a un score de 1)")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['R2']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['R2']['test']))
print("\n")
print("\t --> MAE (Erreur moyenne absolue) en KW")
print("\t \t --> Ensemble d'apprentissage : {}".format(scores['MAE']['train']))
print("\t \t --> Ensemble de test : {}".format(scores['MAE']['test']))

# Sauvergarde des paramètres d'appentissag
with open(scores_file, 'wb') as fp:
    pickle.dump(d_scores, fp)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 6, 100)            40800
#
#  lstm_1 (LSTM)               (None, 6, 50)             30200
#
#  lstm_2 (LSTM)               (None, 10)                2440
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 73,451
# Trainable params: 73,451
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 66/66 [==============================] - 6s 57ms/step - loss: 0.4462 - mae: 0.4822 - val_loss: 0.0897 - val_mae: 0.2082
# Epoch 2/500
# 66/66 [==============================] - 3s 52ms/step - loss: 0.0547 - mae: 0.1632 - val_loss: 0.0179 - val_mae: 0.0951
# Epoch 3/500
# 66/66 [==============================] - 3s 53ms/step - loss: 0.0138 - mae: 0.0807 - val_loss: 0.0097 - val_mae: 0.0641
# Epoch 4/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0096 - mae: 0.0652 - val_loss: 0.0069 - val_mae: 0.0500
# Epoch 5/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0089 - mae: 0.0633 - val_loss: 0.0065 - val_mae: 0.0486
# Epoch 6/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0082 - mae: 0.0598 - val_loss: 0.0074 - val_mae: 0.0617
# Epoch 7/500
# 66/66 [==============================] - 4s 53ms/step - loss: 0.0082 - mae: 0.0616 - val_loss: 0.0059 - val_mae: 0.0481
# Epoch 8/500
# 66/66 [==============================] - 4s 53ms/step - loss: 0.0077 - mae: 0.0591 - val_loss: 0.0088 - val_mae: 0.0673
# Epoch 9/500
# 66/66 [==============================] - 3s 53ms/step - loss: 0.0070 - mae: 0.0553 - val_loss: 0.0061 - val_mae: 0.0552
# Epoch 10/500
# 66/66 [==============================] - 3s 52ms/step - loss: 0.0071 - mae: 0.0575 - val_loss: 0.0047 - val_mae: 0.0413
# Epoch 11/500
# 66/66 [==============================] - 3s 50ms/step - loss: 0.0061 - mae: 0.0509 - val_loss: 0.0063 - val_mae: 0.0543
# Epoch 12/500
# 66/66 [==============================] - 4s 53ms/step - loss: 0.0065 - mae: 0.0544 - val_loss: 0.0045 - val_mae: 0.0425
# Epoch 13/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0064 - mae: 0.0540 - val_loss: 0.0048 - val_mae: 0.0424
# Epoch 14/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0060 - mae: 0.0521 - val_loss: 0.0082 - val_mae: 0.0702
# Epoch 15/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0058 - mae: 0.0512 - val_loss: 0.0055 - val_mae: 0.0506
# Epoch 16/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0058 - mae: 0.0513 - val_loss: 0.0046 - val_mae: 0.0436
# Epoch 17/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0050 - mae: 0.0462 - val_loss: 0.0053 - val_mae: 0.0509
# Epoch 18/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0055 - mae: 0.0507 - val_loss: 0.0042 - val_mae: 0.0408
# Epoch 19/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0050 - mae: 0.0467 - val_loss: 0.0045 - val_mae: 0.0437
# Epoch 20/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0049 - mae: 0.0458 - val_loss: 0.0039 - val_mae: 0.0423
# Epoch 21/500
# 66/66 [==============================] - 4s 53ms/step - loss: 0.0048 - mae: 0.0456 - val_loss: 0.0046 - val_mae: 0.0492
# Epoch 22/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0050 - mae: 0.0476 - val_loss: 0.0038 - val_mae: 0.0395
# Epoch 23/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0047 - mae: 0.0448 - val_loss: 0.0034 - val_mae: 0.0365
# Epoch 24/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0046 - mae: 0.0443 - val_loss: 0.0034 - val_mae: 0.0370
# Epoch 25/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0048 - mae: 0.0466 - val_loss: 0.0034 - val_mae: 0.0362
# Epoch 26/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0046 - mae: 0.0446 - val_loss: 0.0035 - val_mae: 0.0387
# Epoch 27/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0046 - mae: 0.0448 - val_loss: 0.0036 - val_mae: 0.0388
# Epoch 28/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0044 - mae: 0.0432 - val_loss: 0.0046 - val_mae: 0.0468
# Epoch 29/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0042 - mae: 0.0420 - val_loss: 0.0040 - val_mae: 0.0450
# Epoch 30/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0047 - mae: 0.0459 - val_loss: 0.0032 - val_mae: 0.0361
# Epoch 31/500
# 66/66 [==============================] - 4s 54ms/step - loss: 0.0046 - mae: 0.0455 - val_loss: 0.0046 - val_mae: 0.0462
# Epoch 32/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0045 - mae: 0.0447 - val_loss: 0.0033 - val_mae: 0.0370
# Epoch 33/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0046 - mae: 0.0452 - val_loss: 0.0034 - val_mae: 0.0374
# Epoch 34/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0044 - mae: 0.0435 - val_loss: 0.0032 - val_mae: 0.0360
# Epoch 35/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0041 - mae: 0.0416 - val_loss: 0.0031 - val_mae: 0.0352
# Epoch 36/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0042 - mae: 0.0421 - val_loss: 0.0032 - val_mae: 0.0356
# Epoch 37/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0043 - mae: 0.0431 - val_loss: 0.0033 - val_mae: 0.0370
# Epoch 38/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0044 - mae: 0.0444 - val_loss: 0.0031 - val_mae: 0.0348
# Epoch 39/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0045 - mae: 0.0454 - val_loss: 0.0032 - val_mae: 0.0358
# Epoch 40/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0042 - mae: 0.0423 - val_loss: 0.0038 - val_mae: 0.0413
# Epoch 41/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0041 - mae: 0.0420 - val_loss: 0.0033 - val_mae: 0.0381
# Epoch 42/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0040 - mae: 0.0413 - val_loss: 0.0033 - val_mae: 0.0366
# Epoch 43/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0041 - mae: 0.0416 - val_loss: 0.0031 - val_mae: 0.0353
# Epoch 44/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0039 - mae: 0.0407 - val_loss: 0.0039 - val_mae: 0.0451
# Epoch 45/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0040 - mae: 0.0414 - val_loss: 0.0047 - val_mae: 0.0511
# Epoch 46/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0042 - mae: 0.0432 - val_loss: 0.0030 - val_mae: 0.0345
# Epoch 47/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0039 - mae: 0.0402 - val_loss: 0.0033 - val_mae: 0.0381
# Epoch 48/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0042 - mae: 0.0430 - val_loss: 0.0031 - val_mae: 0.0361
# Epoch 49/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0041 - mae: 0.0423 - val_loss: 0.0037 - val_mae: 0.0439
# Epoch 50/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0042 - mae: 0.0432 - val_loss: 0.0032 - val_mae: 0.0366
# Epoch 51/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0401 - val_loss: 0.0031 - val_mae: 0.0354
# Epoch 52/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0044 - mae: 0.0449 - val_loss: 0.0030 - val_mae: 0.0343
# Epoch 53/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0402 - val_loss: 0.0031 - val_mae: 0.0357
# Epoch 54/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0040 - mae: 0.0412 - val_loss: 0.0031 - val_mae: 0.0363
# Epoch 55/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0413 - val_loss: 0.0029 - val_mae: 0.0349
# Epoch 56/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0038 - mae: 0.0399 - val_loss: 0.0030 - val_mae: 0.0360
# Epoch 57/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0039 - mae: 0.0404 - val_loss: 0.0029 - val_mae: 0.0349
# Epoch 58/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0041 - mae: 0.0423 - val_loss: 0.0030 - val_mae: 0.0350
# Epoch 59/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0040 - mae: 0.0414 - val_loss: 0.0036 - val_mae: 0.0433
# Epoch 60/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0041 - mae: 0.0424 - val_loss: 0.0029 - val_mae: 0.0346
# Epoch 61/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0038 - mae: 0.0401 - val_loss: 0.0030 - val_mae: 0.0352
# Epoch 62/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0038 - mae: 0.0397 - val_loss: 0.0029 - val_mae: 0.0345
# Epoch 63/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0408 - val_loss: 0.0033 - val_mae: 0.0397
# Epoch 64/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0412 - val_loss: 0.0037 - val_mae: 0.0429
# Epoch 65/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0039 - mae: 0.0410 - val_loss: 0.0031 - val_mae: 0.0378
# Epoch 66/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0038 - mae: 0.0401 - val_loss: 0.0029 - val_mae: 0.0354
# Epoch 67/500
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0038 - mae: 0.0405 - val_loss: 0.0031 - val_mae: 0.0362
# Epoch 68/500
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0040 - mae: 0.0419 - val_loss: 0.0031 - val_mae: 0.0363
# Epoch 69/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0038 - mae: 0.0402 - val_loss: 0.0029 - val_mae: 0.0348
# Epoch 70/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0037 - mae: 0.0397 - val_loss: 0.0029 - val_mae: 0.0357
# Epoch 71/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0038 - mae: 0.0405 - val_loss: 0.0040 - val_mae: 0.0469
# Epoch 72/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0038 - mae: 0.0407 - val_loss: 0.0029 - val_mae: 0.0347
# Epoch 73/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0039 - mae: 0.0413 - val_loss: 0.0029 - val_mae: 0.0351
# Epoch 74/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0039 - mae: 0.0411 - val_loss: 0.0033 - val_mae: 0.0397
# Epoch 75/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0039 - mae: 0.0416 - val_loss: 0.0028 - val_mae: 0.0341
# Epoch 76/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0038 - mae: 0.0404 - val_loss: 0.0029 - val_mae: 0.0341
# Epoch 77/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0399 - val_loss: 0.0028 - val_mae: 0.0350
# Epoch 78/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0400 - val_loss: 0.0039 - val_mae: 0.0456
# Epoch 79/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0038 - mae: 0.0403 - val_loss: 0.0030 - val_mae: 0.0359
# Epoch 80/500
# 66/66 [==============================] - 4s 55ms/step - loss: 0.0037 - mae: 0.0401 - val_loss: 0.0028 - val_mae: 0.0352
# Epoch 81/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0394 - val_loss: 0.0029 - val_mae: 0.0358
# Epoch 82/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0400 - val_loss: 0.0035 - val_mae: 0.0413
# Epoch 83/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0042 - mae: 0.0447 - val_loss: 0.0033 - val_mae: 0.0404
# Epoch 84/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0399 - val_loss: 0.0028 - val_mae: 0.0345
# Epoch 85/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0029 - val_mae: 0.0355
# Epoch 86/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0393 - val_loss: 0.0029 - val_mae: 0.0359
# Epoch 87/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0398 - val_loss: 0.0030 - val_mae: 0.0357
# Epoch 88/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0392 - val_loss: 0.0028 - val_mae: 0.0342
# Epoch 89/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0029 - val_mae: 0.0356
# Epoch 90/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0037 - mae: 0.0404 - val_loss: 0.0029 - val_mae: 0.0353
# Epoch 91/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0028 - val_mae: 0.0354
# Epoch 92/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0389 - val_loss: 0.0028 - val_mae: 0.0338
# Epoch 93/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0393 - val_loss: 0.0028 - val_mae: 0.0342
# Epoch 94/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0392 - val_loss: 0.0028 - val_mae: 0.0345
# Epoch 95/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0392 - val_loss: 0.0028 - val_mae: 0.0350
# Epoch 96/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0027 - val_mae: 0.0338
# Epoch 97/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0037 - mae: 0.0400 - val_loss: 0.0035 - val_mae: 0.0417
# Epoch 98/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0398 - val_loss: 0.0028 - val_mae: 0.0341
# Epoch 99/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0036 - mae: 0.0390 - val_loss: 0.0031 - val_mae: 0.0381
# Epoch 100/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0398 - val_loss: 0.0030 - val_mae: 0.0368
# Epoch 101/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0037 - mae: 0.0401 - val_loss: 0.0028 - val_mae: 0.0343
# Epoch 102/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0393 - val_loss: 0.0030 - val_mae: 0.0362
# Epoch 103/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0029 - val_mae: 0.0361
# Epoch 104/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0032 - val_mae: 0.0386
# Epoch 105/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0395 - val_loss: 0.0027 - val_mae: 0.0342
# Epoch 106/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0036 - mae: 0.0391 - val_loss: 0.0028 - val_mae: 0.0349
# Epoch 107/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0388 - val_loss: 0.0027 - val_mae: 0.0339
# Epoch 108/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0392 - val_loss: 0.0028 - val_mae: 0.0348
# Epoch 109/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0396 - val_loss: 0.0030 - val_mae: 0.0380
# Epoch 110/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0037 - mae: 0.0402 - val_loss: 0.0027 - val_mae: 0.0340
# Epoch 111/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0035 - mae: 0.0386 - val_loss: 0.0028 - val_mae: 0.0346
# Epoch 112/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0394 - val_loss: 0.0030 - val_mae: 0.0380
# Epoch 113/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0036 - mae: 0.0395 - val_loss: 0.0030 - val_mae: 0.0376
# Epoch 114/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0037 - mae: 0.0402 - val_loss: 0.0027 - val_mae: 0.0344
# Epoch 115/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0393 - val_loss: 0.0027 - val_mae: 0.0341
# Epoch 116/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0037 - mae: 0.0403 - val_loss: 0.0030 - val_mae: 0.0363
# Epoch 117/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0035 - mae: 0.0387 - val_loss: 0.0030 - val_mae: 0.0366
# Epoch 118/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0398 - val_loss: 0.0028 - val_mae: 0.0344
# Epoch 119/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0034 - mae: 0.0382 - val_loss: 0.0033 - val_mae: 0.0402
# Epoch 120/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0035 - mae: 0.0391 - val_loss: 0.0027 - val_mae: 0.0339
# Epoch 121/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0035 - mae: 0.0383 - val_loss: 0.0027 - val_mae: 0.0342
# Epoch 122/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0035 - mae: 0.0389 - val_loss: 0.0027 - val_mae: 0.0337
# Epoch 123/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0034 - mae: 0.0383 - val_loss: 0.0027 - val_mae: 0.0342
# Epoch 124/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0036 - mae: 0.0398 - val_loss: 0.0027 - val_mae: 0.0335
# Epoch 125/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0387 - val_loss: 0.0027 - val_mae: 0.0340
# Epoch 126/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0390 - val_loss: 0.0027 - val_mae: 0.0346
# Epoch 127/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0391 - val_loss: 0.0028 - val_mae: 0.0354
# Epoch 128/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0393 - val_loss: 0.0031 - val_mae: 0.0381
# Epoch 129/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0035 - mae: 0.0387 - val_loss: 0.0028 - val_mae: 0.0349
# Epoch 130/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0390 - val_loss: 0.0027 - val_mae: 0.0338
# Epoch 131/500
# 66/66 [==============================] - 4s 56ms/step - loss: 0.0035 - mae: 0.0390 - val_loss: 0.0030 - val_mae: 0.0380
# Epoch 132/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0035 - mae: 0.0391 - val_loss: 0.0028 - val_mae: 0.0350
# Epoch 133/500
# 66/66 [==============================] - 4s 57ms/step - loss: 0.0034 - mae: 0.0380 - val_loss: 0.0028 - val_mae: 0.0351
# Epoch 134/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0034 - mae: 0.0381 - val_loss: 0.0028 - val_mae: 0.0350
# Epoch 135/500
# 66/66 [==============================] - 4s 58ms/step - loss: 0.0035 - mae: 0.0386 - val_loss: 0.0027 - val_mae: 0.0338
# Epoch 136/500
# 66/66 [==============================] - 4s 59ms/step - loss: 0.0034 - mae: 0.0383 - val_loss: 0.0027 - val_mae: 0.0346
# Epoch 137/500
# 66/66 [==============================] - 4s 60ms/step - loss: 0.0035 - mae: 0.0392 - val_loss: 0.0027 - val_mae: 0.0351
# 328/328 [==============================] - 1s 2ms/step
# 1311/1311 [==============================] - 2s 2ms/step
# Performance du modèle
# 	 --> Score R2 (Le modèle parfait a un score de 1)
# 	 	 --> Ensemble d'apprentissage : 0.997
# 	 	 --> Ensemble de test : 0.996
#
#
# 	 --> MAE (Erreur moyenne absolue) en KW
# 	 	 --> Ensemble d'apprentissage : 276.604
# 	 	 --> Ensemble de test : 268.551

# %% [markdown]
# ### Affichage des prédictions

# %%
from src.prediction import display_prediction

# Calculer les prédictions
# Attention à appliquer la normalisation inverse pour retrouver l'échelle initiale
pred_col_name = ["prediction"]
df_test = pd.DataFrame(data=d_learning_params['scaler'].inverse_transform(y_test), columns=[feat_name],index=idx_test)
df_test[pred_col_name[0]] = d_learning_params['scaler'].inverse_transform(model_lstm.predict(X_test))

# Sauvegarde des résultats
df_test.to_pickle(os.path.join(results_dir, "lstm_predictions_{}_{}.pkl".format(feat_name, str(current_datetime))))

# Afficher les résultats
display_prediction(df_test, target_col_name=feat_name,
                   pred_col_name=pred_col_name, figsize=(14, 8))
# Out:
# 328/328 [==============================] - 1s 2ms/step

# %%
df_test["2017-11-20":"2017-11-30"].plot()
# Out:
# <Axes: >
